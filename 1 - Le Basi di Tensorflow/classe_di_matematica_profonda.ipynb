# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfAI/tf00/blob/master/1%20-%20Le%20Basi%20di%20Tensorflow/classe_di_matematica_profonda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chi passerà matematica V2 ?
# In questo notebook proveremo a migliorare il modello per classificare se uno studente verrà rimandato in matematica, con più informazioni e utilizzandole per addestrare una **Rete Neurale Profonda (DNN - Deep Neural Network)**.

# %% [markdown]
# ## Importiamo i moduli

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ## Creiamo il Dataset
# Importiamo il nuovo dataset, direttamente dal file csv, all'interno di un DataFrame.

# %%
csv_url = "https://raw.githubusercontent.com/ProfAI/tf00/master/datasets/math_class/math_class_deep.csv"
df = pd.read_csv(csv_url)
df.head()
# Out:
#    student_id sex  age  traveltime  ...  internet  romantic  freetime  promoted
# 0           0   F   18           2  ...        no        no         3         0
# 1           1   F   17           1  ...       yes        no         3         0
# 2           2   F   15           1  ...       yes        no         3         1
# 3           3   F   15           1  ...       yes       yes         2         1
# 4           4   F   16           1  ...        no        no         3         1
#
# [5 rows x 14 columns]

# %% [markdown]
# Questa volta abbiamo molte più features:
# * **student_id**: codice identificativo dello studente.
# * **sex**: sesso dello studente (F=Femmina, M=Maschio).
# * **age**: età dello studente.
# * **traveltime**: ore di viaggio per andare e tornare da scuola.
# * **studytime**: ore di studio al giorno.
# * **failures**: numero di volte che lo studene è stato rimandato in matematica in passato.
# * **Medu e Fedu**: rispettivamente grado di istruzione della madre e del padre (0=nessuna, 1=scuola elementare, 2=licenza media, 3=diploma, 4=laurea).
# * **paid**: indica se lo studente prende ripetizioni a pagamento.
# * **higher**: indica se lo studente intende andare all'università.
# * **internet**: indica se lo studente ha accesso ad internet a casa.
# * **romatic**: indica se lo studente è in una relazione amorosa.
# * **freetime**: numero di ore libere a settimana.
# * **absences**: ore di assenze nella classe di matematica per il quadrimestre corrente.
# * **promoted**: variabile booleana (True=1,False=0) che indica se lo studente è stato promosso.
#
# Alcune di queste informazioni sono in formato testuale e ciò non va bene dato che un computer comprende solo numeri. Utilizziamo il *One Hot Encoding* per codificare queste features utilizzando delle variabili dummies.

# %%
to_encode = ["sex", "paid", "higher", "internet", "romantic"]
df[to_encode] = pd.get_dummies(df[to_encode], drop_first=True)
df.head()
# Out:
#    student_id  sex  age  traveltime  ...  internet  romantic  freetime  promoted
# 0           0    0   18           2  ...         0         0         3         0
# 1           1    0   17           1  ...         1         0         3         0
# 2           2    0   15           1  ...         1         0         3         1
# 3           3    0   15           1  ...         1         1         2         1
# 4           4    0   16           1  ...         0         0         3         1
#
# [5 rows x 14 columns]

# %% [markdown]
# Adesso, esattamente come prima, creiamo gli array con features e target.

# %%
X = df.drop(["student_id","promoted"], axis=1).values
y = df["promoted"].values

# %% [markdown]
# ## Creiamo il Modello
# Creiamo la nostra prima Rete Neurale Profonda, per farlo basta aggiungere più strati all'oggett Sequential:
# * Il primo strato è lo strato di input.
# * L'ultimo strato è lo strato di output.
# * Tutti gli strati intermedi sono gli strati nascosti del modello.
#
# Anche per gli strati nascosti dobbiamo specificare una funzione di attivazione, la più
#  comune è la *ReLu*, parleremo approfonditamente delle funzioni di attivazione nella prossima sezione.

# %%
model = keras.models.Sequential([
    keras.layers.Dense(128, input_shape=[X.shape[1]], activation="relu"),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dense(1, activation="sigmoid"),
])

# %% [markdown]
# Utilizzando il metodo *summary* possiamo vedere quanti sono i parametri (pesi e bias) del modello e quanti di questi il modello deve ottimizzare durante la fase di apprendimento.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 128)               1664
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 18,305
# Trainable params: 18,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Dato il numero di strati nascosti che abbiamo inserito, e il numero di neuroni (o nodi) per strato, il nostro modello dovrà apprendere un numero totale di 18.305 parametri. Configuriamo la fase di addestramento, questa volta usiamo **Adam** come algoritmo di ottimizzazione, parleremo approfonditamente degli algoritmi di ottimizzazione nella sezione apposita.

# %%
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %% [markdown]
# Ora avviamo l'addestramento per 200 epoche.

# %%
model.fit(X, y, epochs=200)
# Out:
# Epoch 1/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6985 - accuracy: 0.6329
# Epoch 2/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6408 - accuracy: 0.6759
# Epoch 3/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6120 - accuracy: 0.6835
# Epoch 4/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5989 - accuracy: 0.7013
# Epoch 5/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5896 - accuracy: 0.7139
# Epoch 6/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5878 - accuracy: 0.7291
# Epoch 7/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5783 - accuracy: 0.7418
# Epoch 8/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5857 - accuracy: 0.7266
# Epoch 9/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5945 - accuracy: 0.7139
# Epoch 10/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5697 - accuracy: 0.7468
# Epoch 11/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5686 - accuracy: 0.7190
# Epoch 12/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5735 - accuracy: 0.7316
# Epoch 13/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5698 - accuracy: 0.7367
# Epoch 14/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5614 - accuracy: 0.7266
# Epoch 15/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5802 - accuracy: 0.7165
# Epoch 16/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5769 - accuracy: 0.7190
# Epoch 17/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5766 - accuracy: 0.7215
# Epoch 18/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5857 - accuracy: 0.7291
# Epoch 19/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5732 - accuracy: 0.7165
# Epoch 20/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5582 - accuracy: 0.7316
# Epoch 21/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5627 - accuracy: 0.7266
# Epoch 22/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5647 - accuracy: 0.7241
# Epoch 23/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5602 - accuracy: 0.7241
# Epoch 24/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5745 - accuracy: 0.7089
# Epoch 25/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5716 - accuracy: 0.7241
# Epoch 26/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5643 - accuracy: 0.7114
# Epoch 27/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5595 - accuracy: 0.7190
# Epoch 28/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5686 - accuracy: 0.7215
# Epoch 29/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5551 - accuracy: 0.7190
# Epoch 30/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5500 - accuracy: 0.7165
# Epoch 31/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5502 - accuracy: 0.7241
# Epoch 32/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5605 - accuracy: 0.7342
# Epoch 33/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5505 - accuracy: 0.7241
# Epoch 34/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5541 - accuracy: 0.7215
# Epoch 35/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5780 - accuracy: 0.7114
# Epoch 36/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5556 - accuracy: 0.7215
# Epoch 37/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5436 - accuracy: 0.7291
# Epoch 38/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5532 - accuracy: 0.7266
# Epoch 39/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5485 - accuracy: 0.7241
# Epoch 40/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5489 - accuracy: 0.7190
# Epoch 41/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5440 - accuracy: 0.7241
# Epoch 42/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5460 - accuracy: 0.7241
# Epoch 43/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5490 - accuracy: 0.7342
# Epoch 44/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5441 - accuracy: 0.7291
# Epoch 45/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5429 - accuracy: 0.7494
# Epoch 46/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5600 - accuracy: 0.7266
# Epoch 47/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5458 - accuracy: 0.7266
# Epoch 48/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5414 - accuracy: 0.7316
# Epoch 49/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5424 - accuracy: 0.7342
# Epoch 50/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5396 - accuracy: 0.7291
# Epoch 51/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5552 - accuracy: 0.7241
# Epoch 52/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5310 - accuracy: 0.7392
# Epoch 53/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5404 - accuracy: 0.7418
# Epoch 54/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5583 - accuracy: 0.7165
# Epoch 55/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5311 - accuracy: 0.7392
# Epoch 56/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5389 - accuracy: 0.7367
# Epoch 57/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5401 - accuracy: 0.7443
# Epoch 58/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5378 - accuracy: 0.7418
# Epoch 59/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5347 - accuracy: 0.7342
# Epoch 60/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5305 - accuracy: 0.7418
# Epoch 61/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5315 - accuracy: 0.7367
# Epoch 62/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5386 - accuracy: 0.7418
# Epoch 63/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5376 - accuracy: 0.7494
# Epoch 64/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5201 - accuracy: 0.7494
# Epoch 65/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5211 - accuracy: 0.7418
# Epoch 66/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5230 - accuracy: 0.7468
# Epoch 67/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5359 - accuracy: 0.7367
# Epoch 68/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5232 - accuracy: 0.7392
# Epoch 69/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5275 - accuracy: 0.7392
# Epoch 70/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5167 - accuracy: 0.7494
# Epoch 71/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5208 - accuracy: 0.7519
# Epoch 72/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5152 - accuracy: 0.7367
# Epoch 73/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5165 - accuracy: 0.7367
# Epoch 74/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5164 - accuracy: 0.7544
# Epoch 75/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5131 - accuracy: 0.7544
# Epoch 76/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5179 - accuracy: 0.7595
# Epoch 77/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5072 - accuracy: 0.7367
# Epoch 78/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5116 - accuracy: 0.7722
# Epoch 79/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5092 - accuracy: 0.7620
# Epoch 80/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5108 - accuracy: 0.7468
# Epoch 81/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5037 - accuracy: 0.7570
# Epoch 82/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5125 - accuracy: 0.7570
# Epoch 83/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5034 - accuracy: 0.7570
# Epoch 84/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5015 - accuracy: 0.7722
# Epoch 85/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5329 - accuracy: 0.7367
# Epoch 86/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5112 - accuracy: 0.7620
# Epoch 87/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5155 - accuracy: 0.7646
# Epoch 88/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5091 - accuracy: 0.7494
# Epoch 89/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4999 - accuracy: 0.7595
# Epoch 90/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5034 - accuracy: 0.7620
# Epoch 91/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4960 - accuracy: 0.7646
# Epoch 92/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4961 - accuracy: 0.7519
# Epoch 93/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4975 - accuracy: 0.7620
# Epoch 94/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4963 - accuracy: 0.7772
# Epoch 95/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4937 - accuracy: 0.7823
# Epoch 96/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4899 - accuracy: 0.7620
# Epoch 97/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4899 - accuracy: 0.7747
# Epoch 98/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4865 - accuracy: 0.7722
# Epoch 99/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4894 - accuracy: 0.7696
# Epoch 100/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4882 - accuracy: 0.7722
# Epoch 101/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4805 - accuracy: 0.7873
# Epoch 102/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4831 - accuracy: 0.7696
# Epoch 103/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4807 - accuracy: 0.7772
# Epoch 104/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4856 - accuracy: 0.7848
# Epoch 105/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4795 - accuracy: 0.7722
# Epoch 106/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4982 - accuracy: 0.7595
# Epoch 107/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4757 - accuracy: 0.7772
# Epoch 108/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4829 - accuracy: 0.7848
# Epoch 109/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4886 - accuracy: 0.7924
# Epoch 110/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4801 - accuracy: 0.7747
# Epoch 111/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4818 - accuracy: 0.7797
# Epoch 112/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4775 - accuracy: 0.7797
# Epoch 113/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4748 - accuracy: 0.7873
# Epoch 114/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4921 - accuracy: 0.7646
# Epoch 115/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4691 - accuracy: 0.7772
# Epoch 116/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4739 - accuracy: 0.7823
# Epoch 117/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4900 - accuracy: 0.7797
# Epoch 118/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4898 - accuracy: 0.7772
# Epoch 119/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4647 - accuracy: 0.7873
# Epoch 120/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4611 - accuracy: 0.7975
# Epoch 121/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4643 - accuracy: 0.7797
# Epoch 122/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4620 - accuracy: 0.7924
# Epoch 123/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4566 - accuracy: 0.7899
# Epoch 124/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4704 - accuracy: 0.7646
# Epoch 125/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4560 - accuracy: 0.7848
# Epoch 126/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4589 - accuracy: 0.7823
# Epoch 127/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4586 - accuracy: 0.7899
# Epoch 128/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4618 - accuracy: 0.7899
# Epoch 129/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4516 - accuracy: 0.8051
# Epoch 130/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4482 - accuracy: 0.8025
# Epoch 131/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4456 - accuracy: 0.8076
# Epoch 132/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4503 - accuracy: 0.7924
# Epoch 133/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4505 - accuracy: 0.7924
# Epoch 134/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4487 - accuracy: 0.8051
# Epoch 135/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4394 - accuracy: 0.7975
# Epoch 136/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4467 - accuracy: 0.8101
# Epoch 137/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4420 - accuracy: 0.8127
# Epoch 138/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4375 - accuracy: 0.8051
# Epoch 139/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4511 - accuracy: 0.7772
# Epoch 140/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4541 - accuracy: 0.7899
# Epoch 141/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4433 - accuracy: 0.8177
# Epoch 142/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4525 - accuracy: 0.7848
# Epoch 143/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4650 - accuracy: 0.8000
# Epoch 144/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4471 - accuracy: 0.7747
# Epoch 145/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4413 - accuracy: 0.7924
# Epoch 146/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4374 - accuracy: 0.8076
# Epoch 147/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4315 - accuracy: 0.8152
# Epoch 148/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4387 - accuracy: 0.8051
# Epoch 149/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4237 - accuracy: 0.8177
# Epoch 150/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4224 - accuracy: 0.8329
# Epoch 151/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4290 - accuracy: 0.8076
# Epoch 152/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4236 - accuracy: 0.8177
# Epoch 153/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4169 - accuracy: 0.8127
# Epoch 154/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4158 - accuracy: 0.8253
# Epoch 155/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4207 - accuracy: 0.8253
# Epoch 156/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4357 - accuracy: 0.8076
# Epoch 157/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4257 - accuracy: 0.8177
# Epoch 158/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4159 - accuracy: 0.8203
# Epoch 159/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4172 - accuracy: 0.8152
# Epoch 160/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4289 - accuracy: 0.8051
# Epoch 161/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4214 - accuracy: 0.8203
# Epoch 162/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4149 - accuracy: 0.8430
# Epoch 163/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4186 - accuracy: 0.8203
# Epoch 164/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4093 - accuracy: 0.8203
# Epoch 165/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4115 - accuracy: 0.8228
# Epoch 166/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4083 - accuracy: 0.8304
# Epoch 167/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4009 - accuracy: 0.8278
# Epoch 168/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4040 - accuracy: 0.8405
# Epoch 169/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4115 - accuracy: 0.8228
# Epoch 170/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4089 - accuracy: 0.8354
# Epoch 171/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3969 - accuracy: 0.8228
# Epoch 172/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4025 - accuracy: 0.8304
# Epoch 173/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3924 - accuracy: 0.8354
# Epoch 174/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3939 - accuracy: 0.8354
# Epoch 175/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3938 - accuracy: 0.8354
# Epoch 176/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3900 - accuracy: 0.8430
# Epoch 177/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3909 - accuracy: 0.8304
# Epoch 178/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3869 - accuracy: 0.8354
# Epoch 179/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4016 - accuracy: 0.8228
# Epoch 180/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3988 - accuracy: 0.8354
# Epoch 181/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3930 - accuracy: 0.8228
# Epoch 182/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3891 - accuracy: 0.8380
# Epoch 183/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3941 - accuracy: 0.8253
# Epoch 184/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4281 - accuracy: 0.7848
# Epoch 185/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4100 - accuracy: 0.8152
# Epoch 186/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3898 - accuracy: 0.8253
# Epoch 187/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3868 - accuracy: 0.8354
# Epoch 188/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3884 - accuracy: 0.8329
# Epoch 189/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3769 - accuracy: 0.8329
# Epoch 190/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3774 - accuracy: 0.8405
# Epoch 191/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4124 - accuracy: 0.8127
# Epoch 192/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3778 - accuracy: 0.8456
# Epoch 193/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3918 - accuracy: 0.8304
# Epoch 194/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3839 - accuracy: 0.8253
# Epoch 195/200
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3789 - accuracy: 0.8304
# Epoch 196/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3819 - accuracy: 0.8405
# Epoch 197/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3811 - accuracy: 0.8329
# Epoch 198/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3673 - accuracy: 0.8658
# Epoch 199/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3578 - accuracy: 0.8481
# Epoch 200/200
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3647 - accuracy: 0.8532

# %% [markdown]
# Come vedi, utilizzando più strati e soprattutto più informazioni, il nostro modello ha ottenuto dei risultati decisamente superiori rispetto a quello precedente.

# %% [markdown]
# ## Testiamo la Rete

# %% [markdown]
# Mettiamo all'opera la rete per predire se 3 studenti verranno promossi in matematica, organizziamo le informazioni degli studenti su 3 liste python, che verranno a loro volta inserite in un'altra lista, ricordiamoci di rispettare l'ordine delle colonne (primo valore=sex, secondo valore=age, terzo valore=traveltime ecc...)

# %%
X_test = [[0, 21, 0, 0, 3, 1, 1, 0, 0, 1, 1, 4],
          [1, 18, 1, 4, 0, 4, 4, 1, 1, 1, 0, 2,],
          [0, 19, 2, 2, 0, 2, 2, 1, 0, 1, 1, 0]]

y_pred = model.predict(X_test)
np.round(y_pred, 3)
# Out:
# array([[0.008],
#        [0.916],
#        [0.86 ]], dtype=float32)

# %% [markdown]
# # Qual è la nuova "Formula della Promozione" ?
# In questo caso la risposta è "BOH". E' difficile, se non impossibile, interpretare i risultati di una rete neurale, a causa di ciò che avviene negli strati nascosti e nel numero esorbitante di parametri.

# %%
model.weights
# Out:
# [<tf.Variable 'dense_12/kernel:0' shape=(12, 128) dtype=float32, numpy=
#  array([[ 0.07672337, -0.28676888, -0.15104017, ...,  0.06728674,
#           0.15673201,  0.4058646 ],
#         [-0.04943388,  0.10861004, -0.1478334 , ..., -0.2062072 ,
#          -0.15300967,  0.02394319],
#         [ 0.00332548,  0.05084516, -0.1545011 , ..., -0.09929556,
#          -0.18580717, -0.06273209],
#         ...,
#         [ 0.11875733,  0.10600074, -0.10660829, ...,  0.19594844,
#           0.05514739, -0.00068989],
#         [-0.19464466, -0.13861948, -0.1894843 , ...,  0.1728139 ,
#          -0.0346299 , -0.22514176],
#         [ 0.00552238, -0.18611164, -0.06503865, ..., -0.08583117,
#           0.0103102 ,  0.00725064]], dtype=float32)>,
#  <tf.Variable 'dense_12/bias:0' shape=(128,) dtype=float32, numpy=
#  array([-0.00734606, -0.01670447,  0.        , -0.03219748, -0.1126217 ,
#         -0.05214282, -0.07429194,  0.        , -0.06180031, -0.02649617,
#         -0.07283823, -0.00515311,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.        , -0.01340753,  0.04485266, -0.09763806,
#          0.        , -0.08032405, -0.04820709,  0.        ,  0.01760395,
#          0.        ,  0.        , -0.0015319 ,  0.        ,  0.        ,
#         -0.00826001,  0.        , -0.05270054, -0.01690561,  0.        ,
#          0.        , -0.09342138,  0.        ,  0.        ,  0.        ,
#         -0.04008126, -0.0046853 ,  0.        , -0.03379085,  0.        ,
#          0.        ,  0.03813039, -0.02182828, -0.01828671,  0.02015079,
#          0.        ,  0.        , -0.04607804, -0.03936123,  0.        ,
#         -0.01997566,  0.        ,  0.        , -0.03916603, -0.00509341,
#          0.        ,  0.        , -0.01836057, -0.07800566,  0.        ,
#          0.        ,  0.01747699, -0.02296464,  0.00502052,  0.        ,
#          0.        , -0.02718208,  0.        , -0.06209812,  0.        ,
#          0.04672407, -0.01900959,  0.02061649,  0.04671765, -0.05645159,
#         -0.01934626, -0.00505173,  0.        , -0.01644435,  0.01301861,
#         -0.00525585,  0.        ,  0.        , -0.11626902,  0.00178681,
#         -0.00505223,  0.        , -0.0549681 ,  0.        , -0.08809038,
#          0.05705233,  0.        , -0.07447088, -0.04823595,  0.        ,
#         -0.0238461 , -0.08040164,  0.        , -0.00783083,  0.        ,
#          0.00663441, -0.01744152, -0.04728148,  0.        ,  0.05255055,
#         -0.05493918,  0.        , -0.01362928, -0.05487344,  0.        ,
#         -0.03928404,  0.02097228, -0.03272741,  0.        , -0.00521773,
#          0.        , -0.10916565,  0.        ,  0.00332304, -0.07315191,
#          0.        ,  0.        , -0.08049175], dtype=float32)>,
#  <tf.Variable 'dense_13/kernel:0' shape=(128, 128) dtype=float32, numpy=
#  array([[-0.08308375, -0.0104589 ,  0.13033071, ..., -0.1450128 ,
#           0.14964361, -0.12814312],
#         [ 0.10334603,  0.05074171, -0.12217071, ...,  0.06693995,
#          -0.08704968,  0.10272251],
#         [ 0.03426197, -0.01319425,  0.11081217, ..., -0.01253109,
#          -0.00996143, -0.02336198],
#         ...,
#         [-0.13458022, -0.07262114, -0.13542178, ..., -0.05075016,
#          -0.12064451, -0.12578079],
#         [ 0.13275121,  0.0806139 , -0.05276603, ...,  0.04027827,
#          -0.13261239,  0.10900415],
#         [ 0.05920919,  0.06463044,  0.12691452, ...,  0.02329916,
#           0.00924817, -0.06933013]], dtype=float32)>,
#  <tf.Variable 'dense_13/bias:0' shape=(128,) dtype=float32, numpy=
#  array([-0.01952614, -0.02430823, -0.01069841,  0.0441271 ,  0.01661924,
#          0.        , -0.01189837, -0.02493573,  0.02447763,  0.        ,
#         -0.01170511,  0.        , -0.02382509,  0.01520239,  0.0404833 ,
#          0.        , -0.00588006, -0.00800618, -0.03913752,  0.01396132,
#         -0.02041837,  0.05856304, -0.02550275, -0.02746881,  0.03382176,
#         -0.03514956,  0.00575981, -0.01651797,  0.01236885, -0.02354197,
#         -0.00480169,  0.0062494 ,  0.        , -0.02865458, -0.05785766,
#         -0.01714727,  0.01229499, -0.03291069, -0.02541005,  0.0134291 ,
#         -0.02138614, -0.01402225,  0.01622079, -0.01260135, -0.01426955,
#          0.        ,  0.01633011,  0.03076336, -0.02182651, -0.0113687 ,
#         -0.0138049 , -0.00421214, -0.01598795, -0.01201706,  0.05607566,
#         -0.01039728, -0.02749397, -0.00623594, -0.02160103,  0.        ,
#         -0.0144538 , -0.0083213 , -0.01540631, -0.00596789,  0.03031837,
#          0.        , -0.01363025, -0.0219913 , -0.03516864,  0.02042239,
#          0.01215022, -0.00139911, -0.01255736,  0.03805391,  0.03658521,
#          0.        ,  0.00654974,  0.01111729,  0.        ,  0.        ,
#          0.        , -0.0070801 ,  0.00070191,  0.01375658, -0.02379098,
#          0.01697673,  0.02967261,  0.01066013, -0.02954834, -0.01201339,
#          0.00255663, -0.02663009, -0.02927779,  0.01201065, -0.0157595 ,
#         -0.01065673, -0.00071548,  0.04638613,  0.01452809,  0.00674118,
#          0.00928787,  0.        ,  0.03554591, -0.04943028, -0.01965355,
#          0.        ,  0.        , -0.01240648, -0.01196846, -0.01158292,
#         -0.02430547, -0.03133291, -0.0428655 , -0.01127599,  0.02025594,
#          0.        ,  0.        , -0.01089246, -0.03402704, -0.03052185,
#         -0.02270524, -0.01858748, -0.02995737, -0.0285595 , -0.0212212 ,
#          0.        ,  0.02072599,  0.        ], dtype=float32)>,
#  <tf.Variable 'dense_14/kernel:0' shape=(128, 1) dtype=float32, numpy=
#  array([[-0.00753623],
#         [-0.08113854],
#         [-0.10469106],
#         [ 0.5334108 ],
#         [ 0.14525807],
#         [-0.09942361],
#         [-0.16780019],
#         [-0.01013938],
#         [ 0.13697551],
#         [ 0.20950851],
#         [-0.16407724],
#         [ 0.02558742],
#         [-0.0967036 ],
#         [ 0.20338263],
#         [ 0.08835872],
#         [-0.20693882],
#         [-0.03846779],
#         [-0.15135676],
#         [-0.18998994],
#         [ 0.11682782],
#         [-0.09993451],
#         [ 0.2248171 ],
#         [-0.01133442],
#         [-0.13066897],
#         [ 0.35412067],
#         [-0.14324436],
#         [ 0.11961204],
#         [ 0.15865096],
#         [ 0.10422251],
#         [-0.17077729],
#         [-0.2649131 ],
#         [ 0.13212821],
#         [ 0.19351587],
#         [-0.1284875 ],
#         [ 0.7455288 ],
#         [-0.08327492],
#         [ 0.18672746],
#         [-0.31041303],
#         [ 0.04092863],
#         [ 0.15885742],
#         [-0.05435035],
#         [-0.16825798],
#         [-0.28411984],
#         [ 0.48065   ],
#         [-0.11347883],
#         [ 0.06612059],
#         [ 0.14688757],
#         [-0.20069999],
#         [ 0.13465852],
#         [-0.21742515],
#         [-0.10767856],
#         [ 0.18369031],
#         [-0.05531786],
#         [-0.1786952 ],
#         [ 0.3421207 ],
#         [ 0.18687116],
#         [ 0.06618623],
#         [ 0.11405716],
#         [-0.23397186],
#         [ 0.14045483],
#         [-0.0917275 ],
#         [-0.14161056],
#         [ 0.06020765],
#         [-0.09705224],
#         [ 0.16560932],
#         [-0.16389209],
#         [-0.11364871],
#         [-0.09284977],
#         [-0.12704317],
#         [ 0.5528033 ],
#         [-0.18934721],
#         [ 0.055004  ],
#         [-0.13944207],
#         [ 0.25038412],
#         [ 0.29899514],
#         [ 0.2017676 ],
#         [ 0.17004953],
#         [ 0.1429549 ],
#         [-0.17036766],
#         [-0.03506291],
#         [-0.02428421],
#         [ 0.43777943],
#         [ 0.03761769],
#         [ 0.03565968],
#         [-0.10562207],
#         [ 0.19111468],
#         [ 0.11718448],
#         [ 0.22416116],
#         [-0.17472139],
#         [-0.2052903 ],
#         [ 0.05347509],
#         [-0.0671119 ],
#         [-0.02723736],
#         [ 0.40510052],
#         [ 0.14579006],
#         [-0.01592471],
#         [-0.52704865],
#         [ 0.25368103],
#         [ 0.10872364],
#         [ 0.16608626],
#         [ 0.1375279 ],
#         [ 0.11844519],
#         [ 0.3395008 ],
#         [-0.66372913],
#         [-0.03324917],
#         [ 0.12783855],
#         [ 0.08629262],
#         [-0.15598601],
#         [-0.16565137],
#         [-0.10485189],
#         [-0.04577966],
#         [-0.6080508 ],
#         [-0.04528655],
#         [ 0.06026626],
#         [ 0.26543078],
#         [-0.15323356],
#         [ 0.15282962],
#         [ 0.6665552 ],
#         [-0.67757535],
#         [ 0.19615678],
#         [ 0.08683061],
#         [-0.06122383],
#         [ 0.09077442],
#         [ 0.06676517],
#         [-0.26131576],
#         [-0.14620185],
#         [ 0.46328598],
#         [-0.0451515 ]], dtype=float32)>,
#  <tf.Variable 'dense_14/bias:0' shape=(1,) dtype=float32, numpy=array([0.00950068], dtype=float32)>]
