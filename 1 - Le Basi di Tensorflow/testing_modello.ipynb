# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfAI/tf00/blob/master/1%20-%20Le%20Basi%20di%20Tensorflow/testing_modello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Testing del modello

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
csv_url = "https://raw.githubusercontent.com/ProfAI/tf00/master/1%20-%20Le%20Basi%20di%20Tensorflow/students.csv"
df = pd.read_csv(csv_url, sep=)
df.head()
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1     GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2     GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3     GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4     GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df_sub = df[["studytime", "failures", "absences"]]
df_sub["promosso"] = df["G3"]>=10
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
X = df_sub.drop("promosso", axis=1).values
y = df_sub[["promosso"]].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
model = keras.models.Sequential([
    keras.layers.Dense(1, input_shape=[3], activation="sigmoid")
])

# %%
model.compile(optimizer="sgd", loss="binary_crossentropy", metrics=["accuracy"])

# %%
model.fit(X_train, y_train, epochs=500)
# Out:
# Epoch 1/500
# 9/9 [==============================] - 0s 1ms/step - loss: 0.8797 - accuracy: 0.6123
# Epoch 2/500
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6524 - accuracy: 0.6812
# Epoch 3/500
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6133 - accuracy: 0.7319
# Epoch 4/500
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6142 - accuracy: 0.7246
# Epoch 5/500
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6123 - accuracy: 0.7210
# Epoch 6/500
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6118 - accuracy: 0.7174
# Epoch 7/500
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6098 - accuracy: 0.7210
# Epoch 8/500
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6110 - accuracy: 0.7174
# Epoch 9/500
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6122 - accuracy: 0.7101
# Epoch 10/500
# ...

# %%
model.evaluate(X_train, y_train)
# Out:
# 9/9 [==============================] - 0s 1ms/step - loss: 0.5885 - accuracy: 0.7246
# [0.5885287523269653, 0.7246376872062683]

# %%
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5731 - accuracy: 0.7311
# [0.5730738043785095, 0.7310924530029297]
