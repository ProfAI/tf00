# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfAI/tf00/blob/master/%221%20-%20Le%20Basi%20di%20Tensorflow%22/tf_equation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Approssimare un'equazione

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %% [markdown]
# $$ y = 2x + 1 $$

# %%
x = np.array([3, 5, 8, -1, 10, -7, 0, 11])
y = np.array([7, 11, 17, 1, 21, -13, 1, 23])

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer="sgd", loss="mean_squared_error")

# %%
model.fit(x, y, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4532
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4516
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4501
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4486
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4471
# Epoch 6/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4457
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4443
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4430
# Epoch 9/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4417
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4404
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4392
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4380
# ...

# %%
y_pred = model.predict([2])
print(y_pred)
# Out:
# [[5.30678]]

# %%
y_pred = model.predict([2, -2, 21, 12, -37])
print(y_pred)
# Out:
# [[  5.30678  ]
#  [ -2.5530725]
#  [ 42.64108  ]
#  [ 24.956411 ]
#  [-71.32678  ]]
